# %%
import requests
import json
import pandas as pd
import pprint

# %%
#do the thing here: http://docs.ckan.org/en/ckan-2.3.5/api/#making-an-api-request

pop_url = "https://chronicdata.cdc.gov/api/views/dxpw-cm5u/rows.json?accessType=DOWNLOAD"
metadata_url = "https://catalog.data.gov/harvest/object/c34f57d9-7a0e-400c-a13b-65677c1baeaa"

request = requests.get(pop_url)
print(request.status_code)

pop_data = request.json()
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(pop_data)
# Out:
# 200
# { 'data': [ [ 1,
#               '64395279-3718-47F3-9005-F95BB020DF5D',
#               1,
#               1512396134,
#               '959778',
#               1512396134,
#               '959778',
#               None,
#               'AL',
#               'Birmingham',
#               '0107000',
#               '212237',
#               '19.6',
#               '(19.2, 20.0)',
#               '19.8',
#               '(19.5, 20.2)',
#               '30.9',
#               '(30.8, 31.1)',
#               '31.0',
#               '(30.8, 31.1)',
#               '11.3',
#               '(11.3, 11.4)',
#               '11.2',
#               '(11.1, 11.3)',
#               '43.8',
#               '(43.7, 43.9)',
#               '44.1',
#               '(43.9, 44.2)',
#               '81.3',
#               '(81.2, 81.4)',
#               '70.1',
#               '(70.0, 70.2)',
#               '5.7',
#               '( 5.6,  5.7)',
#               '5.7',
# ...
